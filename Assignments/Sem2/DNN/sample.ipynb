# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "setup-title",
#    "metadata": {},
#    "source": [
#     "# Assignment 1 - Milestones 1 to 4\n",
#     "\n",
#     "This notebook documents dataset selection, preprocessing, baseline model, MLP model, and final comparison."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "id": "setup-path",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import sys\n",
#     "from pathlib import Path\n",
#     "\n",
#     "project_root = Path.cwd()\n",
#     "if str(project_root) not in sys.path:\n",
#     "    sys.path.insert(0, str(project_root))\n",
#     "\n",
#     "print(f'Project root: {project_root}')\n",
#     "print('Python path updated')"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "m1",
#    "metadata": {},
#    "source": [
#     "## Milestone 1 - Dataset Selection & Preprocessing"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "id": "m1-data",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import time\n",
#     "import matplotlib.pyplot as plt\n",
#     "from src.data_pipeline import load_adult_income_data\n",
#     "from src.logistic_regression import LogisticRegressionScratch\n",
#     "from src.metrics import binary_classification_metrics\n",
#     "from src.mlp import MLPScratch\n",
#     "\n",
#     "data = load_adult_income_data(test_size=0.2, random_state=42)\n",
#     "print(f'Dataset: {data.dataset_name}, Train shape: {data.X_train.shape}')"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "m2",
#    "metadata": {},
#    "source": [
#     "## Milestone 2 & 3 - Baseline & MLP"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "m4",
#    "metadata": {},
#    "source": [
#     "## Milestone 4 - Final Results & Comparison\n",
#     "\n",
#     "### Option 1: Load Results from Local JSON File"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "id": "m4-local",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from src.assignment_results import get_assignment_results\n",
#     "\n",
#     "results = get_assignment_results()\n",
#     "print(f\"Baseline test F1: {results['baseline_model']['test_metrics']['f1']:.4f}\")\n",
#     "print(f\"MLP test F1: {results['mlp_model']['test_metrics']['f1']:.4f}\")"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "m4-url-heading",
#    "metadata": {},
#    "source": [
#     "### Option 2: Load Results from URL (e.g., GitHub, Google Drive, or Web Server)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "id": "m4-url",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from src.assignment_results import load_assignment_results_from_url\n",
#     "\n",
#     "# Example: Replace with your actual hosted JSON URL\n",
#     "# url = 'https://raw.githubusercontent.com/your-repo/main/data/assignment_results.json'\n",
#     "# results = load_assignment_results_from_url(url)\n",
#     "\n",
#     "# For now, use local generation (same as Option 1)\n",
#     "results = get_assignment_results()\n",
#     "print(f\"Dataset: {results['dataset_name']}\")\n",
#     "print(f\"Baseline test F1: {results['baseline_model']['test_metrics']['f1']:.4f}\")\n",
#     "print(f\"MLP test F1: {results['mlp_model']['test_metrics']['f1']:.4f}\")"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.9.0"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
